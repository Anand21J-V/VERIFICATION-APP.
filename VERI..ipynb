# %%
'''
import cv2
import pytesseract
from PIL import Image
import json
import pickle

# Path to the Tesseract executable
pytesseract.pytesseract.tesseract_cmd = r'C:\\Program Files\\Tesseract-OCR\\tesseract.exe'

# Open the image file
image = Image.open('C:\\Users\\LENOVO\\Downloads\\ID.jpg')

# Use pytesseract to extract text from the image
text = pytesseract.image_to_string(image)

# Split the text by new lines and filter out empty lines
lines = [line for line in text.split('\n') if line.strip()]

# Initialize an empty dictionary to hold the key-value pairs
data = {}

# Process each line to extract the key-value pairs
for line in lines:
    if ':' in line:
        key, value = line.split(':', 1)
    else:
        key, value = line.split(' ', 1)
    
    key = key.strip().lower()  # Convert keys to lowercase for case insensitivity
    value = value.strip()  # Keep values as they are for accurate comparison
    data[key] = value

# Convert the dictionary into JSON format
json_data = json.dumps(data, indent=4)

# Dump the JSON data into a pickle file for later use
with open('json_data.pkl', 'wb') as f:
    pickle.dump(json_data, f)

# Print the JSON data
print(json_data)

# Predefined keys for input and comparison (converted to lowercase for case insensitivity)
keys = [
    "name", 
    "parent", 
    "course/branch", 
    "enrolment no.", 
    "blood group", 
    "emergency no.", 
    "valid"
]

# Function to compare numbers by allowing minor discrepancies
def compare_numbers(extracted_value, user_value, threshold=1):
    # Ensure both values are treated as strings for easy comparison
    extracted_value = str(extracted_value)
    user_value = str(user_value)
    
    # If lengths differ significantly, they are not the same
    if len(extracted_value) != len(user_value):
        return False
    
    # Count the number of differing digits
    differences = sum(1 for a, b in zip(extracted_value, user_value) if a != b)
    
    # Allow verification if the number of differing digits is within the threshold
    return differences <= threshold

# Function to compare the values (case-insensitive for text, with special handling for numbers)
def compare_values(extracted_value, user_value):
    if extracted_value.isdigit() and user_value.isdigit():
        return compare_numbers(extracted_value, user_value)
    else:
        return extracted_value.lower() == user_value.lower()

# Take input from the user for each key and verify against the extracted data
verification_results = {}
for key in keys:
    user_value = input(f"Enter the value for {key.capitalize()}: ").strip()
    
    # Check if the key exists in the extracted data and if the value matches
    if key in data and compare_values(data[key], user_value):
        print(f"{key.capitalize()}: VERIFIED")
        verification_results[key] = "VERIFIED"
    else:
        print(f"{key.capitalize()}: NOT VERIFIED")
        verification_results[key] = "NOT VERIFIED"

# Save the verification results to a pickle file
with open('verification_results.pkl', 'wb') as f:
    pickle.dump(verification_results, f)

# Save the entire model including the extracted data and verification results
model_data = {
    'extracted_data': data,
    'verification_results': verification_results
}

with open('model.pkl', 'wb') as f:
    pickle.dump(model_data, f)
'''
# Out:
# {
#     "name": "Anand Vishwakarma",
#     "parent": "Arun Vishwakarma",
#     "course/branch": "B.Tech - CSE",
#     "enroliment no.": "8T22CS013",
#     "blaod group": "O+ve",
#     "em\u00e9tgency no.": "9925150588",
#     "valid": "Till 2022-2026"
# }
# Enter the value for Name: ANAND VISHWAKARMA
# Name: VERIFIED
# Enter the value for Parent: ARUN VISWHAKARAM
# Parent: NOT VERIFIED
# Enter the value for Course/branch: B.tech - cse
# Course/branch: VERIFIED
# Enter the value for Enrolment no.: 8T22CS013
# Enrolment no.: NOT VERIFIED
# Enter the value for Blood group: o+ve
# Blood group: NOT VERIFIED
# Enter the value for Emergency no.: 9925150588
# Emergency no.: NOT VERIFIED
# Enter the value for Valid: till 2022-2026
# Valid: VERIFIED

# %%
'''
import cv2
import pytesseract
from PIL import Image
import json
import pickle

# Path to the Tesseract executable
pytesseract.pytesseract.tesseract_cmd = r'C:\\Program Files\\Tesseract-OCR\\tesseract.exe'

# Open the image file
image = Image.open('C:\\Users\\LENOVO\\Downloads\\ID.jpg')

# Use pytesseract to extract text from the image
text = pytesseract.image_to_string(image)

# Split the text by new lines and filter out empty lines
lines = [line for line in text.split('\n') if line.strip()]

# Initialize an empty dictionary to hold the key-value pairs
data = {}

# Process each line to extract the key-value pairs
for line in lines:
    if ':' in line:
        key, value = line.split(':', 1)
    else:
        key, value = line.split(' ', 1)
    
    key = key.strip()  # Retain the original case
    value = value.strip()  # Retain the original case
    data[key] = value

# Convert the dictionary into JSON format
json_data = json.dumps(data, indent=4)

# Dump the JSON data into a pickle file
with open('json_data.pkl', 'wb') as f:
    pickle.dump(json_data, f)

# Predefined keys for input and comparison
keys = [
    "Name", 
    "Parent", 
    "Course/Branch", 
    "Enroliment No.", 
    "Blaod Group", 
    "Emétgency No.", 
    "Valid"
]

# Collect all inputs from the user at once
user_data = {}
for key in keys:
    user_value = input(f"Enter the value for {key}: ").strip()
    user_data[key] = user_value

# Check if all inputs are correct (case-sensitive)
all_verified = True
for key, user_value in user_data.items():
    if key in data and data[key] != user_value:
        all_verified = False
        break

# Print the final verification result
if all_verified:
    print("VERIFIED")
else:
    print("NOT VERIFIED")
# SAVING THE MODEL    
with open('model.pkl', 'wb') as f:
    pickle.dump(model_data, f)
'''
# Out:
# Enter the value for Name: anand vishwakarma
# Enter the value for Parent: arun vishwakarma
# Enter the value for Course/Branch: b.tech - cse
# Enter the value for Enroliment No.: 8t22cs013
# Enter the value for Blaod Group: o+ve
# Enter the value for Emétgency No.: 9925150588
# Enter the value for Valid: till 2022-2026
# NOT VERIFIED

# %% [markdown]
# ## MAIN CODE

# %%
import pytesseract
from PIL import Image
import json
import pickle

# Set the path for the Tesseract-OCR executable
pytesseract.pytesseract.tesseract_cmd = r'C:\\Program Files\\Tesseract-OCR\\tesseract.exe'

# Open the image file
image = Image.open('C:\\Users\\LENOVO\\Downloads\\ID.jpg')

# Use pytesseract to extract text from the image
text = pytesseract.image_to_string(image)

# Split the text by new lines and filter out empty lines
lines = [line for line in text.split('\n') if line.strip()]

# Initialize an empty dictionary to hold the key-value pairs
data = {}

# Process each line to extract the key-value pairs
for line in lines:
    if ':' in line:
        key, value = line.split(':', 1)
        key = key.strip()
        value = value.strip()
        data[key] = value
    else:
        parts = line.split(' ', 1)
        if len(parts) == 2:
            key, value = parts
            key = key.strip()
            value = value.strip()
            data[key] = value

# Convert the dictionary into JSON format
json_data = json.dumps(data, indent=4)

# Save the JSON data into a pickle file
with open('json_data.pkl', 'wb') as f:
    pickle.dump(json_data, f)

# Print the JSON data
print("Extracted Data in JSON Format:")
print(json_data)

# Predefined keys for input and comparison
keys = [
    "Name", 
    "Parent", 
    "Course/Branch", 
    "Enrollment No.", 
    "Blood Group", 
    "Emergency No.", 
    "Valid"
]

# Function to convert value to integer if possible
def to_integer(value):
    try:
        return int(value)
    except ValueError:
        return value

# Take input from the user for each key and verify against the extracted data
verification_results = {}
for key in keys:
    user_value = input(f"Enter the value for {key}: ").strip()
    
    # Convert user input to integer if possible
    user_value = to_integer(user_value)
    
    # Convert extracted data to integer if possible
    if key in data:
        extracted_value = data[key]
        extracted_value = to_integer(extracted_value)
        
        # Check if the key exists in the extracted data and if the value matches
        if extracted_value == user_value:
            print(f"{key}: VERIFIED")
            verification_results[key] = "VERIFIED"
        else:
            print(f"{key}: NOT VERIFIED")
            verification_results[key] = "NOT VERIFIED"
    else:
        print(f"{key}: KEY NOT FOUND")
        verification_results[key] = "KEY NOT FOUND"

# Save the verification results into a pickle file
with open('verification.pkl', 'wb') as f:
    pickle.dump(verification_results, f)
# Out:
# Extracted Data in JSON Format:
# {
#     "Name": "Anand Vishwakarma",
#     "Parent": "Arun Vishwakarma",
#     "Course/Branch": "B.Tech - CSE",
#     "Enroliment No.": "8T22CS013",
#     "Blaod Group": "O+ve",
#     "Em\u00e9tgency No.": "9925150588",
#     "Valid": "Till 2022-2026"
# }
# Enter the value for Name: Anand Vishwakarma
# Name: VERIFIED
# Enter the value for Parent: Arun Vishwakarma
# Parent: VERIFIED
# Enter the value for Course/Branch: B.Tech - CSE
# Course/Branch: VERIFIED
# Enter the value for Enrollment No.: 8T22CS013
# Enrollment No.: KEY NOT FOUND
# Enter the value for Blood Group: O+ve
# Blood Group: KEY NOT FOUND
# Enter the value for Emergency No.: 9925150588
# Emergency No.: KEY NOT FOUND
# Enter the value for Valid: Till 2022-2026
# Valid: VERIFIED
#
# Verification results have been saved to 'verification.pkl'.

# %%
import pytesseract
from PIL import Image
import json
import pickle

# Set the path for the Tesseract-OCR executable
pytesseract.pytesseract.tesseract_cmd = r'C:\\Program Files\\Tesseract-OCR\\tesseract.exe'

# Open the image file
image = Image.open('C:\\Users\\LENOVO\\Downloads\\ID.jpg')

# Use pytesseract to extract text from the image
text = pytesseract.image_to_string(image)

# Split the text by new lines and filter out empty lines
lines = [line for line in text.split('\n') if line.strip()]

# Initialize an empty dictionary to hold the key-value pairs
data = {}

# Process each line to extract the key-value pairs
for line in lines:
    if ':' in line:
        key, value = line.split(':', 1)
        key = key.strip().lower()  # Convert to lowercase for flexible matching
        value = value.strip()
        data[key] = value
    else:
        parts = line.split(' ', 1)
        if len(parts) == 2:
            key, value = parts
            key = key.strip().lower()  # Convert to lowercase for flexible matching
            value = value.strip()
            data[key] = value

# Convert the dictionary into JSON format
json_data = json.dumps(data, indent=4)

# Save the JSON data into a pickle file
with open('json_data.pkl', 'wb') as f:
    pickle.dump(json_data, f)

# Print the JSON data
print("Extracted Data in JSON Format:")
print(json_data)

# Predefined keys for input and comparison
keys = [
    "Name", 
    "Parent", 
    "Course/Branch", 
    "Enrollment No.", 
    "Blood Group", 
    "Emergency No.", 
    "Valid"
]

# Function to normalize values for comparison
def normalize(value):
    try:
        # Try to convert to integer
        return int(value)
    except ValueError:
        try:
            # Try to convert to float
            return float(value)
        except ValueError:
            # Convert to lowercase string for case-insensitive comparison
            return str(value).strip().lower()

# Take input from the user for each key and verify against the extracted data
verification_results = {}
for key in keys:
    normalized_key = key.strip().lower()  # Normalize key for flexible matching
    user_value = input(f"Enter the value for {key}: ").strip()
    
    # Normalize user input
    user_value = normalize(user_value)
    
    # Normalize and compare extracted data
    if normalized_key in data:
        extracted_value = normalize(data[normalized_key])
        
        # Check if the key exists in the extracted data and if the value matches
        if extracted_value == user_value:
            print(f"{key}: VERIFIED")
            verification_results[key] = "VERIFIED"
        else:
            print(f"{key}: NOT VERIFIED")
            verification_results[key] = "NOT VERIFIED"
    else:
        print(f"{key}: KEY NOT FOUND")
        verification_results[key] = "KEY NOT FOUND"

# Save the verification results into a pickle file
with open('verification.pkl', 'wb') as f:
    pickle.dump(verification_results, f)
